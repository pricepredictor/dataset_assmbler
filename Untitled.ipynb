# %%
import shapely.geometry
import pyproj
import json
import statistics
import numpy as np
import pandas as pd


from entrie import Entrie, EntrieType
from utils import *

# %%
city_dict = {
    'spb': {
        'center': (59.9343, 30.3351)
    },
    'smr': {
        'center': (53.2415, 50.2212)
        
    }
}

def prepare_table(city_abbr):
    flats = pd.read_csv(
        f'./data/flats/{city_abbr}.csv').drop(columns=['adress', 'subway_station'])
    cols = flats.columns.tolist()
    cols[-1], cols[-2] = cols[-2], cols[-1]
    cols = cols[-2:] + [cols[0]] + cols[1:-2]
    flats = flats[cols]
    flats['price_per_m'] = (
        flats['price'] / flats['area']).map(lambda x: int(x))
    flats = flats.drop(columns=['price'])
    flats['distance_to_center'] = [distance(
        x, city_dict[city_abbr]['center']) for x in zip(flats.latitude, flats.longitude)]
    return flats

# %%
def add_distances(city_abbr):
    with open(f'./data/entries/parsed/{city_abbr}.json') as file:
        entry_data = json.load(file)

# %%
def assemble_dataset(city_abbr):
    with open(f'./data/entries/parsed/{city_abbr}.json') as file:
        entry_data = json.load(file)

    flats = prepare_table(city_abbr)

    R = 6371
    feature_list = []
    i = 0
    for row in flats.iterrows():
        i += 1
        row = row[1]
        row_dict = {
            'price_per_m': int(row['price_per_m']),
            'rooms': int(row['rooms']),
            'area': row['area'],
            'floor': int(row['floor']),
            'floors_total': int(row['floors_total']),
            'distance_to_subway': int(row['distance to subway']),
            'distance_to_center': int(row['distance_to_center'])
        }
        lat, lon = row['latitude'], row['longitude']
        for entry_type, entries in zip(entry_data.keys(), entry_data.values()):
            c = np.array([entry[0]
                          for entry in entries if type(entry[0][0]) is float]).T
            d = c.copy()
            d[0] -= lat
            d[0] *= (np.pi / 180)
            d[1] -= lon
            d[1] *= (np.pi / 180)
            a = np.sin(d[0] / 2) * np.sin(d[0] / 2)
            c = 2 * arctan2(np.sqrt(a), np.sqrt(1 - a)) + np.cos(lat * np.pi / 180) * \
                np.cos(c[0] * np.pi / 180) * \
                np.sin(d[1] / 2) * np.sin(d[1] / 2)
            distances = R * c * 1000
            if entry_type == 'shop' and np.nonzero(distances <= 1000)[0].shape[0] == 0:
                break
            for r in [500, 1000]:
                indices = np.nonzero(distances <= r)[0]
                if entry_type in ['vacancy']:
                    salaries = [entries[i][1] for i in indices] or [0]
                    median = int(statistics.median(salaries))
                    mean = int(statistics.mean(salaries))
                    row_dict[f'mean_salaries_{r}'] = mean
                    row_dict[f'median_salaries_{r}'] = median
                row_dict[f'{entry_type}_{str(r)}'] = indices.shape[0]
        else:
            feature_list.append(row_dict)
        if i % 1000 == 0:
            print(i)

    dataset = pd.DataFrame(feature_list)
    dataset.to_csv(f'./datasets/{city_abbr}.csv', index=False)

# %%
city_abbr = 'smr'
with open(f'./data/entries/parsed/{city_abbr}.json') as file:
    entry_data = json.load(file)

flats = prepare_table(city_abbr)

# %%
a = np.arange(4)

# %%
a.astype(float)
# Out:
# array([0., 1., 2., 3.])

# %%
p = 0.017453292519943295
feature_list = []
i = 0
for row in flats[:10].iterrows():
    i += 1
    row = row[1]
    row_dict = {
        'price_per_m': int(row['price_per_m']),
        'rooms': int(row['rooms']),
        'area': row['area'],
        'floor': int(row['floor']),
        'floors_total': int(row['floors_total']),
        'distance_to_subway': int(row['distance to subway']),
        'distance_to_center': int(row['distance_to_center'])
    }
    lat1, lon1 = row['latitude'], row['longitude']
    for entry_type, entries in zip(entry_data.keys(), entry_data.values()):
        c = np.array([entry[0]
                      for entry in entries if type(entry[0][0]) is float]).T
        lat2 = c[0]
        lon2 = c[1]
        a = 0.5 - np.cos((lat2 - lat1) * p)/2 + np.cos(lat1 * p) * np.cos(lat2 * p) * (1 - np.cos((lon2 - lon1) * p)) / 2
        distances = (12742000 * np.arcsin(np.sqrt(a))).astype(int)

        if entry_type == 'shop' and np.nonzero(distances <= 1000)[0].shape[0] == 0:
            break
            
        if entry_type in ['school', 'bus_stop']:
            row_dict[f'distance_to_{entry_type}'] = min(distances)        
        for r in [500, 1000]:
            indices = np.nonzero(distances <= r)[0]
            if entry_type in ['vacancy']:
                salaries = [entries[i][1] for i in indices] or [0]
                median = int(statistics.median(salaries))
                mean = int(statistics.mean(salaries))
                row_dict[f'mean_salaries_{r}'] = mean
                row_dict[f'median_salaries_{r}'] = median
            row_dict[f'{entry_type}_{str(r)}'] = indices.shape[0]
    else:
        feature_list.append(row_dict)
        
    if i % 1000 == 0:
        print(i)

# %%
feature_list
# Out:
# [{'price_per_m': 63063,
#   'rooms': 2,
#   'area': 44.4,
#   'floor': 5,
#   'floors_total': 9,
#   'distance_to_subway': 3800,
#   'distance_to_center': 1712,
#   'shop_500': 4,
#   'shop_1000': 21,
#   'distance_to_bus_stop': 106,
#   'bus_stop_500': 8,
#   'bus_stop_1000': 18,
#   'tram_stop_500': 2,
#   'tram_stop_1000': 5,
#   'subway_station_500': 0,
#   'subway_station_1000': 0,
#   'cafe_500': 1,
#   'cafe_1000': 3,
#   'office_500': 1,
#   'office_1000': 2,
#   'point_of_interest_500': 0,
#   'point_of_interest_1000': 0,
#   'distance_to_school': 448,
#   'school_500': 1,
#   'school_1000': 3,
#   'hospital_500': 0,
#   'hospital_1000': 0,
#   'bank_500': 2,
#   'bank_1000': 5,
#   'univercity_500': 0,
#   'univercity_1000': 0,
#   'cinema_500': 0,
#   'cinema_1000': 0,
#   'nightlife_500': 0,
#   'nightlife_1000': 0,
#   'government_500': 1,
#   'government_1000': 1,
#   'leisure_500': 0,
#   'leisure_1000': 0,
#   'hotel_500': 0,
#   'hotel_1000': 0,
#   'mean_salaries_500': 0,
#   'median_salaries_500': 0,
#   'vacancy_500': 0,
#   'mean_salaries_1000': 64,
#   'median_salaries_1000': 64,
#   'vacancy_1000': 1},
#  {'price_per_m': 73837,
#   'rooms': 2,
#   'area': 86.0,
#   'floor': 10,
#   'floors_total': 12,
#   'distance_to_subway': 2300,
#   'distance_to_center': 2907,
#   'shop_500': 6,
#   'shop_1000': 11,
#   'distance_to_bus_stop': 175,
#   'bus_stop_500': 1,
#   'bus_stop_1000': 11,
#   'tram_stop_500': 0,
#   'tram_stop_1000': 0,
#   'subway_station_500': 0,
#   'subway_station_1000': 0,
#   'cafe_500': 0,
#   'cafe_1000': 1,
#   'office_500': 0,
#   'office_1000': 0,
#   'point_of_interest_500': 1,
#   'point_of_interest_1000': 5,
#   'distance_to_school': 960,
#   'school_500': 0,
#   'school_1000': 1,
#   'hospital_500': 0,
#   'hospital_1000': 0,
#   'bank_500': 2,
#   'bank_1000': 4,
#   'univercity_500': 1,
#   'univercity_1000': 1,
#   'cinema_500': 0,
#   'cinema_1000': 0,
#   'nightlife_500': 1,
#   'nightlife_1000': 2,
#   'government_500': 0,
#   'government_1000': 1,
#   'leisure_500': 0,
#   'leisure_1000': 0,
#   'hotel_500': 0,
#   'hotel_1000': 1,
#   'mean_salaries_500': 33,
#   'median_salaries_500': 32,
#   'vacancy_500': 14,
#   'mean_salaries_1000': 37,
#   'median_salaries_1000': 34,
#   'vacancy_1000': 38},
#  {'price_per_m': 100274,
#   'rooms': 2,
#   'area': 72.8,
#   'floor': 8,
#   'floors_total': 14,
#   'distance_to_subway': 1900,
#   'distance_to_center': 8718,
#   'shop_500': 6,
#   'shop_1000': 28,
#   'distance_to_bus_stop': 197,
#   'bus_stop_500': 2,
#   'bus_stop_1000': 51,
#   'tram_stop_500': 2,
#   'tram_stop_1000': 12,
#   'subway_station_500': 0,
#   'subway_station_1000': 0,
#   'cafe_500': 2,
#   'cafe_1000': 32,
#   'office_500': 1,
#   'office_1000': 11,
#   'point_of_interest_500': 2,
#   'point_of_interest_1000': 13,
#   'distance_to_school': 457,
#   'school_500': 1,
#   'school_1000': 2,
#   'hospital_500': 0,
#   'hospital_1000': 1,
#   'bank_500': 1,
#   'bank_1000': 9,
#   'univercity_500': 0,
#   'univercity_1000': 4,
#   'cinema_500': 0,
#   'cinema_1000': 0,
#   'nightlife_500': 0,
#   'nightlife_1000': 2,
#   'government_500': 0,
#   'government_1000': 6,
#   'leisure_500': 0,
#   'leisure_1000': 1,
#   'hotel_500': 0,
#   'hotel_1000': 2,
#   'mean_salaries_500': 39,
#   'median_salaries_500': 35,
#   'vacancy_500': 19,
#   'mean_salaries_1000': 41,
#   'median_salaries_1000': 40,
#   'vacancy_1000': 129},
#  {'price_per_m': 56074,
#   'rooms': 2,
#   'area': 42.8,
#   'floor': 1,
#   'floors_total': 5,
#   'distance_to_subway': 700,
#   'distance_to_center': 5642,
#   'shop_500': 18,
#   'shop_1000': 46,
#   'distance_to_bus_stop': 481,
#   'bus_stop_500': 1,
#   'bus_stop_1000': 21,
#   'tram_stop_500': 0,
#   'tram_stop_1000': 8,
#   'subway_station_500': 0,
#   'subway_station_1000': 1,
#   'cafe_500': 2,
#   'cafe_1000': 8,
#   'office_500': 0,
#   'office_1000': 1,
#   'point_of_interest_500': 0,
#   'point_of_interest_1000': 1,
#   'distance_to_school': 964,
#   'school_500': 0,
#   'school_1000': 1,
#   'hospital_500': 1,
#   'hospital_1000': 2,
#   'bank_500': 2,
#   'bank_1000': 3,
#   'univercity_500': 0,
#   'univercity_1000': 0,
#   'cinema_500': 0,
#   'cinema_1000': 1,
#   'nightlife_500': 0,
#   'nightlife_1000': 1,
#   'government_500': 0,
#   'government_1000': 0,
#   'leisure_500': 2,
#   'leisure_1000': 2,
#   'hotel_500': 1,
#   'hotel_1000': 1,
#   'mean_salaries_500': 31,
#   'median_salaries_500': 28,
#   'vacancy_500': 16,
#   'mean_salaries_1000': 33,
#   'median_salaries_1000': 31,
#   'vacancy_1000': 48},
#  {'price_per_m': 48863,
#   'rooms': 2,
#   'area': 44.0,
#   'floor': 5,
#   'floors_total': 5,
#   'distance_to_subway': 3700,
#   'distance_to_center': 1845,
#   'shop_500': 4,
#   'shop_1000': 19,
#   'distance_to_bus_stop': 255,
#   'bus_stop_500': 8,
#   'bus_stop_1000': 15,
#   'tram_stop_500': 3,
#   'tram_stop_1000': 5,
#   'subway_station_500': 0,
#   'subway_station_1000': 0,
#   'cafe_500': 1,
#   'cafe_1000': 3,
#   'office_500': 1,
#   'office_1000': 3,
#   'point_of_interest_500': 0,
#   'point_of_interest_1000': 0,
#   'distance_to_school': 459,
#   'school_500': 1,
#   'school_1000': 3,
#   'hospital_500': 0,
#   'hospital_1000': 0,
#   'bank_500': 1,
#   'bank_1000': 5,
#   'univercity_500': 0,
#   'univercity_1000': 0,
#   'cinema_500': 0,
#   'cinema_1000': 0,
#   'nightlife_500': 0,
#   'nightlife_1000': 0,
#   'government_500': 1,
#   'government_1000': 1,
#   'leisure_500': 0,
#   'leisure_1000': 0,
#   'hotel_500': 0,
#   'hotel_1000': 0,
#   'mean_salaries_500': 0,
#   'median_salaries_500': 0,
#   'vacancy_500': 0,
#   'mean_salaries_1000': 29,
#   'median_salaries_1000': 20,
#   'vacancy_1000': 5},
#  {'price_per_m': 109210,
#   'rooms': 2,
#   'area': 76.0,
#   'floor': 3,
#   'floors_total': 6,
#   'distance_to_subway': 3900,
#   'distance_to_center': 10826,
#   'shop_500': 9,
#   'shop_1000': 19,
#   'distance_to_bus_stop': 455,
#   'bus_stop_500': 5,
#   'bus_stop_1000': 38,
#   'tram_stop_500': 0,
#   'tram_stop_1000': 13,
#   'subway_station_500': 0,
#   'subway_station_1000': 0,
#   'cafe_500': 5,
#   'cafe_1000': 22,
#   'office_500': 3,
#   'office_1000': 5,
#   'point_of_interest_500': 6,
#   'point_of_interest_1000': 15,
#   'distance_to_school': 542,
#   'school_500': 0,
#   'school_1000': 3,
#   'hospital_500': 0,
#   'hospital_1000': 0,
#   'bank_500': 2,
#   'bank_1000': 4,
#   'univercity_500': 0,
#   'univercity_1000': 2,
#   'cinema_500': 0,
#   'cinema_1000': 0,
#   'nightlife_500': 0,
#   'nightlife_1000': 4,
#   'government_500': 2,
#   'government_1000': 5,
#   'leisure_500': 0,
#   'leisure_1000': 0,
#   'hotel_500': 1,
#   'hotel_1000': 3,
#   'mean_salaries_500': 38,
#   'median_salaries_500': 33,
#   'vacancy_500': 4,
#   'mean_salaries_1000': 36,
#   'median_salaries_1000': 28,
#   'vacancy_1000': 13},
#  {'price_per_m': 115789,
#   'rooms': 2,
#   'area': 76.0,
#   'floor': 24,
#   'floors_total': 25,
#   'distance_to_subway': 2300,
#   'distance_to_center': 9475,
#   'shop_500': 6,
#   'shop_1000': 22,
#   'distance_to_bus_stop': 123,
#   'bus_stop_500': 12,
#   'bus_stop_1000': 34,
#   'tram_stop_500': 6,
#   'tram_stop_1000': 13,
#   'subway_station_500': 0,
#   'subway_station_1000': 0,
#   'cafe_500': 8,
#   'cafe_1000': 33,
#   'office_500': 2,
#   'office_1000': 4,
#   'point_of_interest_500': 8,
#   'point_of_interest_1000': 18,
#   'distance_to_school': 770,
#   'school_500': 0,
#   'school_1000': 1,
#   'hospital_500': 1,
#   'hospital_1000': 1,
#   'bank_500': 3,
#   'bank_1000': 9,
#   'univercity_500': 3,
#   'univercity_1000': 5,
#   'cinema_500': 0,
#   'cinema_1000': 0,
#   'nightlife_500': 1,
#   'nightlife_1000': 9,
#   'government_500': 3,
#   'government_1000': 6,
#   'leisure_500': 0,
#   'leisure_1000': 0,
#   'hotel_500': 0,
#   'hotel_1000': 2,
#   'mean_salaries_500': 43,
#   'median_salaries_500': 47,
#   'vacancy_500': 61,
#   'mean_salaries_1000': 42,
#   'median_salaries_1000': 40,
#   'vacancy_1000': 94},
#  {'price_per_m': 84146,
#   'rooms': 2,
#   'area': 82.0,
#   'floor': 14,
#   'floors_total': 17,
#   'distance_to_subway': 900,
#   'distance_to_center': 5028,
#   'shop_500': 10,
#   'shop_1000': 48,
#   'distance_to_bus_stop': 632,
#   'bus_stop_500': 0,
#   'bus_stop_1000': 18,
#   'tram_stop_500': 0,
#   'tram_stop_1000': 5,
#   'subway_station_500': 0,
#   'subway_station_1000': 0,
#   'cafe_500': 2,
#   'cafe_1000': 11,
#   'office_500': 1,
#   'office_1000': 5,
#   'point_of_interest_500': 0,
#   'point_of_interest_1000': 6,
#   'distance_to_school': 622,
#   'school_500': 0,
#   'school_1000': 3,
#   'hospital_500': 1,
#   'hospital_1000': 4,
#   'bank_500': 0,
#   'bank_1000': 4,
#   'univercity_500': 0,
#   'univercity_1000': 0,
#   'cinema_500': 0,
#   'cinema_1000': 0,
#   'nightlife_500': 0,
#   'nightlife_1000': 2,
#   'government_500': 1,
#   'government_1000': 5,
#   'leisure_500': 2,
#   'leisure_1000': 4,
#   'hotel_500': 3,
#   'hotel_1000': 3,
#   'mean_salaries_500': 29,
#   'median_salaries_500': 22,
#   'vacancy_500': 4,
#   'mean_salaries_1000': 42,
#   'median_salaries_1000': 32,
#   'vacancy_1000': 30},
#  {'price_per_m': 44285,
#   'rooms': 2,
#   'area': 35.0,
#   'floor': 1,
#   'floors_total': 3,
#   'distance_to_subway': 2500,
#   'distance_to_center': 9077,
#   'shop_500': 11,
#   'shop_1000': 20,
#   'distance_to_bus_stop': 140,
#   'bus_stop_500': 14,
#   'bus_stop_1000': 53,
#   'tram_stop_500': 5,
#   'tram_stop_1000': 8,
#   'subway_station_500': 0,
#   'subway_station_1000': 0,
#   'cafe_500': 4,
#   'cafe_1000': 13,
#   'office_500': 3,
#   'office_1000': 7,
#   'point_of_interest_500': 8,
#   'point_of_interest_1000': 11,
#   'distance_to_school': 656,
#   'school_500': 0,
#   'school_1000': 1,
#   'hospital_500': 1,
#   'hospital_1000': 3,
#   'bank_500': 4,
#   'bank_1000': 5,
#   'univercity_500': 0,
#   'univercity_1000': 0,
#   'cinema_500': 0,
#   'cinema_1000': 0,
#   'nightlife_500': 1,
#   'nightlife_1000': 1,
#   'government_500': 0,
#   'government_1000': 3,
#   'leisure_500': 0,
#   'leisure_1000': 1,
#   'hotel_500': 1,
#   'hotel_1000': 2,
#   'mean_salaries_500': 43,
#   'median_salaries_500': 40,
#   'vacancy_500': 26,
#   'mean_salaries_1000': 37,
#   'median_salaries_1000': 32,
#   'vacancy_1000': 74}]

# %%
p = (lat, lon)
loc_list = [[53.209791, 50.119632], [53.2255334, 50.2065899], [53.2257518, 50.2067186], [53.1854754, 50.0888691], [53.1851968, 50.0851277], [53.1844514, 50.0915613], [53.2021505, 50.1261779], [53.202022, 50.1260036], [53.2048135, 50.1280141], [53.2434004, 50.2424113], [53.2352408, 50.2493883], [53.2352375, 50.2488545], [53.1899902, 50.1271579], [53.2170603, 50.1731793], [53.1989219, 50.1118837], [53.2122188, 50.1352057], [53.1968171, 50.1688869], [53.2020622, 50.1971705], [53.2128207, 50.1749329], [53.2039186, 50.212989], [53.2143275, 50.1997608], [53.2230922, 50.2539185], [53.2432563, 50.2367658], [53.2212365, 50.2296546], [53.2316979, 50.2491872], [53.2084214, 50.2771666], [53.1943079, 50.2187004], [53.2082647, 50.2371019], [53.2448454, 50.2649155], [53.2523423, 50.2503027], [53.2073922, 50.1585215], [53.19692, 50.2138518], [53.2413452, 50.1867492]]# To display all data use the following two lines, but, since your data has
sorted([distance(p, point) for point in loc_list])
# Out:
# [449,
#  678,
#  701,
#  1343,
#  1346,
#  1350,
#  1735,
#  2736,
#  3057,
#  3494,
#  3517,
#  3947,
#  4355,
#  4740,
#  4808,
#  5262,
#  5851,
#  5947,
#  5962,
#  6042,
#  6134,
#  7277,
#  7565,
#  8302,
#  9126,
#  9351,
#  9386,
#  9404,
#  10122,
#  10388,
#  12402,
#  12488,
#  12714]

# %%
import folium

map_ = folium.Map(location=[40.13, 116.25], zoom_start=10)

for point in loc_list:
    folium.Marker(point, icon=folium.Icon(color='green')).add_to(map_)

folium.Marker(p, icon=folium.Icon(color='red')).add_to(map_)

# To display first 1000 points
# for point in range(0, 1000):
#     folium.Marker(loc_list[point]).add_to(map_)

map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
min(a)
# Out:
# 0
